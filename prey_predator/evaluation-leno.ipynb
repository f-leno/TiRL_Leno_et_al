# %%
#matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
sns.set(style="darkgrid")

# %%
#from exp_utils import collect_experiment_data, summarize_experiment_data
import exp_utils
#source1 = '/home/ruben/playground/HFO/experiments/EVAL/2016_09_12-14.38.02_SARSA_1_5'


printCI = False
source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/Dummy-2-none-none'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QAverage-2-reuseQ-none'
source3 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QBias-2-reuseQ-none'
source4 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-none'
source5 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-none'

name1 = 'Dummy-2-none'
name2 = 'QAverage-2-reuseQ'
name3 = 'QBias-2-reuseQ'
name4 = 'QLearning-2-none'
name5 = 'QManualMapping-2'


exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)
exp_utils.collect_experiment_data(source3, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source3,hfo=False)
exp_utils.collect_experiment_data(source4, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source4,hfo=False)
exp_utils.collect_experiment_data(source5, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source5,hfo=False)



xMinStep = None
xMaxStep = None
yMinStep = None
yMaxStep = None

xMinBudget = None
xMaxBudget = None
yMinBudget = None
yMaxBudget = None



#exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,
#                     name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI)


exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,#,source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured",
                    )


printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-reward'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-reward'
source3 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QAverage-2-reuseQ-reward'
source4 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QBias-2-reuseQ-reward'
source5 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-reward'

name1 = 'QLearning-2-none-reward'
name2 = 'Regular'
name3 = 'QAverage-2-reuseQ-reward'
name4 = 'QBias-2-reuseQ-reward'
name5 = 'QManualMapping-2-reuseQ-reward'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)
exp_utils.collect_experiment_data(source3, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source3,hfo=False)
exp_utils.collect_experiment_data(source4, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source4,hfo=False)
exp_utils.collect_experiment_data(source5, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source5,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,source5=source5,#,source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured"
                    )


printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-none'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QAverage-2-reuseQ-negative'
source3 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QBias-2-reuseQ-negative'
source4 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-negative'

name1 = 'Regular'
name2 = 'QAverage-2-reuseQ-negative'
name3 = 'QBias-2-reuseQ-negative'
name4 = 'QManualMapping-2-reuseQ-negative'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)
exp_utils.collect_experiment_data(source3, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source3,hfo=False)
exp_utils.collect_experiment_data(source4, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source4,hfo=False)
exp_utils.collect_experiment_data(source5, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source5,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,#source5=source5,#,source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured"
                    )


printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-transition'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QAverage-2-reuseQ-transition'
source3 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QBias-2-reuseQ-transition'
source4 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-transition'

name1 = 'Regular'
name2 = 'QAverage-2-reuseQ-transition'
name3 = 'QBias-2-reuseQ-transition'
name4 = 'QManualMapping-2-reuseQ-transition'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)
exp_utils.collect_experiment_data(source3, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source3,hfo=False)
exp_utils.collect_experiment_data(source4, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source4,hfo=False)
#exp_utils.collect_experiment_data(source5, runs = 1000,hfo=False)
#exp_utils.summarize_experiment_data(source5,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,#source5=source5,#,source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured"
                    )


printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-2-none-none'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QAverage-2-reuseQ-goldmine'
source3 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QBias-2-reuseQ-goldmine'
source4 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-goldmine'

name1 = 'Regular'
name2 = 'QAverage-2-reuseQ-goldmine'
name3 = 'QBias-2-reuseQ-goldmine'
name4 = 'QManualMapping-2-reuseQ-goldmine'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)
exp_utils.collect_experiment_data(source3, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source3,hfo=False)
exp_utils.collect_experiment_data(source4, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source4,hfo=False)
#exp_utils.collect_experiment_data(source5, runs = 1000,hfo=False)
#exp_utils.summarize_experiment_data(source5,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,#source5=source5,#,source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured"
                    )

#exp_utils.draw_graph(source1=source1, source2=source2,,  source3=source3,#source4 = source4,source5=source5,source6=source6,
#                     name6=name6,name5=name5,name4=name4, name3=name3,name1=name1, name2=name2, what="__SUMMARY_stepscaptured",ci=printCI)
#exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4=source4,name4=name4,name5=name5,
                     #name3=name3,name1=name1, name2=name2,what="__SUMMARY_budgets",ci=printCI)
#exp_utils.draw_graph(source1=source1, source2=source2,source3=source3,source4 = source4,source5=source5,
#                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
#                    ci=printCI,xMin = xMinStep, yMin=yMinStep, xMax = xMaxStep, yMax=yMaxStep,what="__SUMMARY_stepscaptured")

#exp_utils.draw_graph(source3=source3,source4 = source4,source5=source5,
#                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
#                    ci=printCI,xMin = xMinBudget, yMin=yMinBudget, xMax = xMaxBudget, yMax=yMaxBudget,
#                     what="__SUMMARY_budgets")

#exp_utils.draw_graph(source1=source1, source2=source2,#, source3=source3,source4 = source4,#source5=source5,
#                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
                   # ci=printCI,xMin = xMinPerc, yMin=yMinPerc, xMax = xMaxPerc, yMax=yMaxPerc)
#exp_utils.draw_graph(source1=source1, source2=source2,#,  source3=source3,source4 = source4,source6=source6,source5=source5,
#                    name5=name5,name4=name4, name3=name3,name1=name1, name2=name2,name6=name6, what="__SUMMARY_stepscaptured",ci=printCI,
#                    xMin = xMinStep, yMin=yMinStep, xMax = xMaxStep, yMax=yMaxStep)
#exp_utils.draw_graph(source1=source1, source2=source2, source3=source3, source4=source4,ci=False)
#exp_utils.draw_graph(source1=source1, source2=source2,source3=source3,source4=source4, what="__SUMMARY_goaltimes",ci=False)
#exp_utils.draw_graph(source1=source1, source2=source2,source3=source3,source4=source4, what="__SUMMARY_budgets",ci=False)


printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-1-saveQ-none'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/Dummy-1-none-none'

name1 = 'QLearning-1-saveQ-none'
name2 = 'Dummy-1-none-none'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,# source3=source3,source4 = source4,source5=source5,#source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured",
                    )

printCI = False

source1 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/QLearning-1-saveQ-goldmine'
source2 = '/home/leno/gitProjects/TiRL_Leno_et_al/log/Dummy-1-none-goldmine'

name1 = 'QLearning-1-saveQ-goldmine'
name2 = 'Dummy-1-none-goldmine'

exp_utils.collect_experiment_data(source1, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source1,hfo=False)
exp_utils.collect_experiment_data(source2, runs = 1000,hfo=False)
exp_utils.summarize_experiment_data(source2,hfo=False)

exp_utils.draw_graph(source1=source1, source2=source2,# source3=source3,source4 = source4,source5=source5,#source6=source6,
                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI,what="__SUMMARY_stepscaptured",
                    )
# Out:
# /home/leno/.conda/envs/leno/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Error 30 - 277 , 451
# Error 30 - 277 , 451
# Error 30 - 277 , 451
# Could use 29 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 29
# Error 4 - 193 , 451
# Error 4 - 193 , 451
# Error 4 - 193 , 451
# Could use 3 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 3
# Error 4 - 160 , 451
# Error 4 - 160 , 451
# Error 4 - 160 , 451
# Could use 3 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 3
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Could use 2 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 2
# Error 3 - 174 , 451
# Error 3 - 174 , 451
# Error 3 - 174 , 451
# Could use 2 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 2
# Error 19 - 166 , 451
# Error 19 - 166 , 451
# Error 19 - 166 , 451
# Could use 18 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 18
# Error 19 - 166 , 451
# Error 19 - 166 , 451
# Error 19 - 166 , 451
# Could use 18 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 18
# Error 27 - 268 , 451
# Error 27 - 268 , 451
# Error 27 - 268 , 451
# Could use 26 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 26
# Error 27 - 323 , 451
# Error 27 - 323 , 451
# Error 27 - 323 , 451
# Could use 26 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 26
# Error 19 - 318 , 451
# Error 19 - 318 , 451
# Error 19 - 318 , 451
# Could use 18 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 18
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Could use 2 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 2
# Could use 1 runs from expected 1000
# len(evalUsedBudgets) 1191 --> <type 'list'> 1
# /home/leno/.conda/envs/leno/lib/python2.7/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# Could use 1 runs from expected 1000
# len(evalUsedBudgets) 936 --> <type 'list'> 1
# Error 2 - 187 , 451
# Error 2 - 187 , 451
# Error 2 - 187 , 451
# Could use 1 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 1
# Error 19 - 318 , 451
# Error 19 - 318 , 451
# Error 19 - 318 , 451
# Could use 18 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 18
# Error 31 - 139 , 451
# Error 31 - 139 , 451
# Error 31 - 139 , 451
# Could use 30 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 30
# Error 33 - 179 , 451
# Error 33 - 179 , 451
# Error 33 - 179 , 451
# Could use 32 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 32
# Error 32 - 305 , 451
# Error 32 - 305 , 451
# Error 32 - 305 , 451
# Could use 31 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 31
# /home/leno/.conda/envs/leno/lib/python2.7/site-packages/numpy/lib/npyio.py:893: UserWarning: loadtxt: Empty input file: "<open file '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-transition/_0_1_AGENT_1_RESULTS_eval', mode 'rb' at 0x7f3b2b03f540>"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# Error 27 - 385 , 451
# /home/leno/.conda/envs/leno/lib/python2.7/site-packages/numpy/lib/npyio.py:893: UserWarning: loadtxt: Empty input file: "<open file '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-transition/_0_1_AGENT_2_RESULTS_eval', mode 'rb' at 0x7f3b2b03f540>"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# Error 27 - 385 , 451
# /home/leno/.conda/envs/leno/lib/python2.7/site-packages/numpy/lib/npyio.py:893: UserWarning: loadtxt: Empty input file: "<open file '/home/leno/gitProjects/TiRL_Leno_et_al/log/QManualMapping-2-reuseQ-transition/_0_1_AGENT_3_RESULTS_eval', mode 'rb' at 0x7f3b2b03f540>"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# Error 27 - 385 , 451
# Could use 25 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 25
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Error 3 - 170 , 451
# Error 50 - 0 , 451
# Could use 2 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 2
# Error 7 - 169 , 451
# Error 7 - 169 , 451
# Error 7 - 169 , 451
# Could use 6 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 6
# Error 9 - 18 , 451
# Error 9 - 18 , 451
# Error 9 - 18 , 451
# Could use 8 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 8
# Error 5 - 271 , 451
# Error 5 - 271 , 451
# Error 5 - 271 , 451
# Could use 4 runs from expected 1000
# len(evalUsedBudgets) 1353 --> <type 'list'> 4
# Could use 100 runs from expected 1000
# len(evalUsedBudgets) 753 --> <type 'list'> 100
# Error 98 - 70 , 251
# Error 98 - 70 , 251
# Error 98 - 70 , 251
# Could use 97 runs from expected 1000
# len(evalUsedBudgets) 753 --> <type 'list'> 97
# Could use 50 runs from expected 1000
# len(evalUsedBudgets) 753 --> <type 'list'> 50
# Error 50 - 52 , 251
# Error 50 - 52 , 251
# Error 50 - 52 , 251
# Could use 49 runs from expected 1000
# len(evalUsedBudgets) 753 --> <type 'list'> 49
